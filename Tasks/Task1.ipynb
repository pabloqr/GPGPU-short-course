# %% [markdown]
# # Task 1
#
# Esta es una prueba para la tarea 1.

# %%
import numpy as np

# Task 5
x = np.linspace(-1, 1, 20)

# Task 6
import matplotlib.pyplot as plt

def f(x):
    return x*x

plt.plot(x, f(x))

def g(x):
    return 2*x

plt.plot(x, g(x))
plt.grid("on")
